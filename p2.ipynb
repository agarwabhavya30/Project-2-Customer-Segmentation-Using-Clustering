# %%
import pandas as pd

# %%
data=pd.read_csv("customer_support_tickets.csv")

# %%
data
# Out:
#       Ticket ID        Customer Name              Customer Email  \
# 0             1        Marisa Obrien  carrollallison@example.com
# 1             2         Jessica Rios    clarkeashley@example.com
# 2             3  Christopher Robbins   gonzalestracy@example.com
# 3             4     Christina Dillon    bradleyolson@example.org
# 4             5    Alexander Carroll     bradleymark@example.com
# ...         ...                  ...                         ...
# 8464       8465           David Todd          adam28@example.net
# 8465       8466           Lori Davis       russell68@example.com
# 8466       8467      Michelle Kelley        ashley83@example.org
# 8467       8468     Steven Rodriguez         fpowell@example.org
# 8468       8469      Steven Davis MD          lori20@example.net
#
#       Customer Age Customer Gender       Product Purchased Date of Purchase  \
# 0               32           Other              GoPro Hero       22-03-2021
# 1               42          Female             LG Smart TV       22-05-2021
# 2               48           Other                Dell XPS       14-07-2020
# 3               27          Female        Microsoft Office       13-11-2020
# 4               67          Female        Autodesk AutoCAD       04-02-2020
# ...            ...             ...                     ...              ...
# 8464            22          Female                 LG OLED       08-12-2021
# 8465            27          Female  Bose SoundLink Speaker       22-02-2020
# 8466            57          Female     GoPro Action Camera       17-08-2021
# 8467            54            Male             PlayStation       16-10-2021
# 8468            53           Other      Philips Hue Lights       01-06-2020
#
#           Ticket Type            Ticket Subject  \
# 0     Technical issue             Product setup
# 1     Technical issue  Peripheral compatibility
# 2     Technical issue           Network problem
# 3     Billing inquiry            Account access
# 4     Billing inquiry                 Data loss
# ...               ...                       ...
# 8464  Product inquiry      Installation support
# 8465  Technical issue            Refund request
# 8466  Technical issue            Account access
# 8467  Product inquiry             Payment issue
# 8468  Billing inquiry            Hardware issue
#
#                                      Ticket Description  \
# 0     I'm having an issue with the {product_purchase...
# 1     I'm having an issue with the {product_purchase...
# 2     I'm facing a problem with my {product_purchase...
# 3     I'm having an issue with the {product_purchase...
# 4     I'm having an issue with the {product_purchase...
# ...                                                 ...
# 8464  My {product_purchased} is making strange noise...
# 8465  I'm having an issue with the {product_purchase...
# 8466  I'm having an issue with the {product_purchase...
# 8467  I'm having an issue with the {product_purchase...
# 8468  There seems to be a hardware problem with my {...
#
#                   Ticket Status  \
# 0     Pending Customer Response
# 1     Pending Customer Response
# 2                        Closed
# 3                        Closed
# 4                        Closed
# ...                         ...
# 8464                       Open
# 8465                       Open
# 8466                     Closed
# 8467                     Closed
# 8468                       Open
#
#                                          Resolution Ticket Priority  \
# 0                                               NaN        Critical
# 1                                               NaN        Critical
# 2      Case maybe show recently my computer follow.             Low
# 3     Try capital clearly never color toward story.             Low
# 4                       West decision evidence bit.             Low
# ...                                             ...             ...
# 8464                                            NaN             Low
# 8465                                            NaN        Critical
# 8466          Eight account century nature kitchen.            High
# 8467                          We seat culture plan.          Medium
# 8468                                            NaN            High
#
#      Ticket Channel First Response Time Time to Resolution  \
# 0      Social media    01-06-2023 12:15                NaN
# 1              Chat    01-06-2023 16:45                NaN
# 2      Social media    01-06-2023 11:14   01-06-2023 18:05
# 3      Social media    01-06-2023 07:29   01-06-2023 01:57
# 4             Email    01-06-2023 00:12   01-06-2023 19:53
# ...             ...                 ...                ...
# 8464          Phone                 NaN                NaN
# 8465          Email                 NaN                NaN
# 8466   Social media    01-06-2023 09:44   01-06-2023 04:31
# 8467          Email    01-06-2023 18:28   01-06-2023 05:32
# 8468          Phone                 NaN                NaN
#
#       Customer Satisfaction Rating
# 0                              NaN
# 1                              NaN
# 2                              3.0
# 3                              3.0
# 4                              1.0
# ...                            ...
# 8464                           NaN
# 8465                           NaN
# 8466                           3.0
# 8467                           3.0
# 8468                           NaN
#
# [8469 rows x 17 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8469 entries, 0 to 8468
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Ticket ID                     8469 non-null   int64
#  1   Customer Name                 8469 non-null   object
#  2   Customer Email                8469 non-null   object
#  3   Customer Age                  8469 non-null   int64
#  4   Customer Gender               8469 non-null   object
#  5   Product Purchased             8469 non-null   object
#  6   Date of Purchase              8469 non-null   object
#  7   Ticket Type                   8469 non-null   object
#  8   Ticket Subject                8469 non-null   object
#  9   Ticket Description            8469 non-null   object
#  10  Ticket Status                 8469 non-null   object
#  11  Resolution                    2769 non-null   object
#  12  Ticket Priority               8469 non-null   object
#  13  Ticket Channel                8469 non-null   object
#  14  First Response Time           5650 non-null   object
#  15  Time to Resolution            2769 non-null   object
#  16  Customer Satisfaction Rating  2769 non-null   float64
# dtypes: float64(1), int64(2), object(14)
# memory usage: 1.1+ MB

# %%
data.fillna(data.median(numeric_only=True), inplace=True)

# %%
data.isnull().sum()
# Out:
# Ticket ID                          0
# Customer Name                      0
# Customer Email                     0
# Customer Age                       0
# Customer Gender                    0
# Product Purchased                  0
# Date of Purchase                   0
# Ticket Type                        0
# Ticket Subject                     0
# Ticket Description                 0
# Ticket Status                      0
# Resolution                      5700
# Ticket Priority                    0
# Ticket Channel                     0
# First Response Time             2819
# Time to Resolution              5700
# Customer Satisfaction Rating       0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Ticket ID                       0
# Customer Name                   0
# Customer Email                  0
# Customer Age                    0
# Customer Gender                 0
# Product Purchased               0
# Date of Purchase                0
# Ticket Type                     0
# Ticket Subject                  0
# Ticket Description              0
# Ticket Status                   0
# Resolution                      0
# Ticket Priority                 0
# Ticket Channel                  0
# First Response Time             0
# Time to Resolution              0
# Customer Satisfaction Rating    0
# dtype: int64

# %%
data.fillna(data.median(numeric_only=True), inplace=True)

# %%
for col in data.columns:
    if data[col].dtype == 'object':   # Categorical
        data[col].fillna(data[col].mode()[0], inplace=True)

# %%
data["Date"] = pd.to_datetime(data["First Response Time"])
data["Age"] = data["Customer Age"].astype(int)

# %%
data.drop_duplicates(inplace=True)

# %%
data["Customer Name"] = data["Customer Name"].str.lower()

# %%
data["Customer Name"] = data["Customer Name"].str.strip()

# %%
data
# Out:
#       Ticket ID        Customer Name              Customer Email  \
# 2             3  Christopher Robbins   gonzalestracy@example.com
# 3             4     Christina Dillon    bradleyolson@example.org
# 4             5    Alexander Carroll     bradleymark@example.com
# 10           11        Joseph Moreno          mbrown@example.org
# 11           12       Brandon Arnold       davisjohn@example.net
# ...         ...                  ...                         ...
# 8452       8453         Craig Forbes       jessica60@example.org
# 8453       8454        Paula Vazquez       wanderson@example.com
# 8455       8456            Ariel Lee  thompsonsamuel@example.org
# 8466       8467      Michelle Kelley        ashley83@example.org
# 8467       8468     Steven Rodriguez         fpowell@example.org
#
#       Customer Age Customer Gender          Product Purchased  \
# 2               48           Other                   Dell XPS
# 3               27          Female           Microsoft Office
# 4               67          Female           Autodesk AutoCAD
# 10              48            Male            Nintendo Switch
# 11              51            Male  Microsoft Xbox Controller
# ...            ...             ...                        ...
# 8452            62          Female                MacBook Pro
# 8453            61           Other                     iPhone
# 8455            54           Other       Dyson Vacuum Cleaner
# 8466            57          Female        GoPro Action Camera
# 8467            54            Male                PlayStation
#
#      Date of Purchase           Ticket Type            Ticket Subject  \
# 2          14-07-2020       Technical issue           Network problem
# 3          13-11-2020       Billing inquiry            Account access
# 4          04-02-2020       Billing inquiry                 Data loss
# 10         19-01-2021  Cancellation request                 Data loss
# 11         24-10-2021       Product inquiry              Software bug
# ...               ...                   ...                       ...
# 8452       29-03-2020        Refund request             Display issue
# 8453       20-06-2020       Billing inquiry  Peripheral compatibility
# 8455       02-02-2021       Billing inquiry            Refund request
# 8466       17-08-2021       Technical issue            Account access
# 8467       16-10-2021       Product inquiry             Payment issue
#
#                                      Ticket Description Ticket Status  \
# 2     I'm facing a problem with my {product_purchase...        Closed
# 3     I'm having an issue with the {product_purchase...        Closed
# 4     I'm having an issue with the {product_purchase...        Closed
# 10    I'm having an issue with the {product_purchase...        Closed
# 11    I'm having an issue with the {product_purchase...        Closed
# ...                                                 ...           ...
# 8452  I'm having an issue with the {product_purchase...        Closed
# 8453  The {product_purchased} is unable to establish...        Closed
# 8455  I've recently set up my {product_purchased}, b...        Closed
# 8466  I'm having an issue with the {product_purchase...        Closed
# 8467  I'm having an issue with the {product_purchase...        Closed
#
#                                              Resolution Ticket Priority  \
# 2          Case maybe show recently my computer follow.             Low
# 3         Try capital clearly never color toward story.             Low
# 4                           West decision evidence bit.             Low
# 10                Measure tonight surface feel forward.            High
# 11    Measure there house management pick knowledge ...            High
# ...                                                 ...             ...
# 8452                  Interesting show must successful.        Critical
# 8453                            Skill expect admit and.            High
# 8455                  Say position key appear behavior.            High
# 8466              Eight account century nature kitchen.            High
# 8467                              We seat culture plan.          Medium
#
#      Ticket Channel First Response Time Time to Resolution  \
# 2      Social media    01-06-2023 11:14   01-06-2023 18:05
# 3      Social media    01-06-2023 07:29   01-06-2023 01:57
# 4             Email    01-06-2023 00:12   01-06-2023 19:53
# 10            Phone    01-06-2023 17:46   31-05-2023 23:51
# 11             Chat    01-06-2023 12:05   01-06-2023 09:27
# ...             ...                 ...                ...
# 8452          Phone    01-06-2023 14:14   01-06-2023 05:47
# 8453           Chat    01-06-2023 12:56   01-06-2023 04:45
# 8455          Email    01-06-2023 14:15   01-06-2023 06:58
# 8466   Social media    01-06-2023 09:44   01-06-2023 04:31
# 8467          Email    01-06-2023 18:28   01-06-2023 05:32
#
#       Customer Satisfaction Rating
# 2                              3.0
# 3                              3.0
# 4                              1.0
# 10                             1.0
# 11                             1.0
# ...                            ...
# 8452                           3.0
# 8453                           5.0
# 8455                           1.0
# 8466                           3.0
# 8467                           3.0
#
# [2769 rows x 17 columns]
